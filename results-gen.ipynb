# %%
import utils

# %%
simulations = [utils.medium_name]
algs = [utils.gen_name, utils.pso_name, utils.cmaes_name]
plots = [utils.ch_iter_time]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pavel/dev/diplom/tssproblem/results-gen.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/home/pavel/dev/diplom/tssproblem/results-gen.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> simulations = [utils.medium_name]
#       <a href='vscode-notebook-cell:/home/pavel/dev/diplom/tssproblem/results-gen.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> algs = [utils.gen_name, utils.pso_name, utils.cmaes_name]
#       <a href='vscode-notebook-cell:/home/pavel/dev/diplom/tssproblem/results-gen.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> plots = [utils.ch_iter_time]
#
# AttributeError: module 'utils' has no attribute 'medium_name'

# %%
for simulation in simulations:
    for alg in algs:
        # %run {alg}.py {simulation}

# %%
for simulation in simulations:
    for plot in plots:
        utils.plot(simulation, plot)

# %%
import utils
utils.histogram()

# %% [markdown]
# | Alg | Map | X-best | Fitness | Generations | Evaluations | Runtime (s) | Avg iter time |
# |------|------|------------|---------|------------|-------------|-------------|-------------|
# | cmaes | commercial | [46, 31, 30, 49, 30, 30] | 29.25 | 75 | 675 | 134.66 | 1.8 |
# | gen  | commercial | [48, 34, 31, 53, 31, 31] | 30.12 | 400 | 5938 | 1107.73 | 2.77 |
